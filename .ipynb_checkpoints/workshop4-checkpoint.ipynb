# %% [markdown]
# # Regresión lineal simple
# Es un modelo usado para entender la relación lineal de dos variables asumiendo que una variable (independiente) puede predecir el otro (dependiente).
#
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
#
# En donde la beta0 representa la línea que intercepta a y, la beta1 representa la pendiente de la recta.
#
# Pero, el modelo del mercado no es exacto y no puede depender de esa sola función, por lo cual se necesita agregar una variable para representar el error:
# ![%E5%9B%BE%E7%89%87-2.png](attachment:%E5%9B%BE%E7%89%87-2.png)

# %%
import pandas_datareader as pdr
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# Getting price data and selecting adjusted price columns:
sprices = pdr.get_data_yahoo(['ALFAA.MX','^MXX'],start="01/01/2018", end="07/31/2022",interval="m")
sprices = sprices['Adj Close']

# Calculating returns:
sr = np.log(sprices) - np.log(sprices.shift(1))
# Deleting the first month with NAs:
sr=sr.dropna()
sr.columns=['ALFAA','MXX']

# %%
sr.plot.scatter(x='MXX', y='ALFAA',c='DarkBlue')
plt.show()

# %%
# Scatter plots can be misleading when ranges of X and Y are very different.
# In this case, Alfa had a very bad month in the COVID crisis with more than 60% loss!! 
# Then, we can re-do the scatter plot trying to make the X and Y axis using the same range of values 
plt.clf()
x=sr['MXX']
y = sr['ALFAA']
plt.scatter(x, y)
# Now I add the regression line:
b1,b0 = np.polyfit(x,y,1)
yfit = b0+b1*x

plt.plot(x, yfit,c="orange")

plt.xticks(np.arange(-0.50,0.5,0.1))
plt.xlabel("Market returns")
plt.ylabel("Alfa returns")

plt.show()

# %%
# Another faster way to plot a scatter and the regression line:
# I use the seaborn library:
import seaborn as sns
plt.clf()

sns.regplot(x, y)
plt.xticks(np.arange(-0.50,0.5,0.1))
plt.xlabel("Market returns")
plt.ylabel("Alfa returns")

plt.show()
# Out:
# C:\Users\Keyuan\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import statsmodels.api as sm
X = sm.add_constant(x)

mkmodel = sm.OLS(y,X).fit()
 
print(mkmodel.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  ALFAA   R-squared:                       0.351
# Model:                            OLS   Adj. R-squared:                  0.339
# Method:                 Least Squares   F-statistic:                     28.69
# Date:                Sat, 20 Aug 2022   Prob (F-statistic):           1.87e-06
# Time:                        23:11:51   Log-Likelihood:                 43.927
# No. Observations:                  55   AIC:                            -83.85
# Df Residuals:                      53   BIC:                            -79.84
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0079      0.015     -0.526      0.601      -0.038       0.022
# MXX            1.5389      0.287      5.357      0.000       0.963       2.115
# ==============================================================================
# Omnibus:                        9.454   Durbin-Watson:                   2.205
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):               22.417
# Skew:                          -0.137   Prob(JB):                     1.36e-05
# Kurtosis:                       6.116   Cond. No.                         19.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.formula.api as smf

mkmodel2 = smf.ols('ALFAA ~ MXX',data=sr).fit()
 
print(mkmodel2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  ALFAA   R-squared:                       0.351
# Model:                            OLS   Adj. R-squared:                  0.339
# Method:                 Least Squares   F-statistic:                     28.69
# Date:                Sat, 20 Aug 2022   Prob (F-statistic):           1.87e-06
# Time:                        23:13:35   Log-Likelihood:                 43.927
# No. Observations:                  55   AIC:                            -83.85
# Df Residuals:                      53   BIC:                            -79.84
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0079      0.015     -0.526      0.601      -0.038       0.022
# MXX            1.5389      0.287      5.357      0.000       0.963       2.115
# ==============================================================================
# Omnibus:                        9.454   Durbin-Watson:                   2.205
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):               22.417
# Skew:                          -0.137   Prob(JB):                     1.36e-05
# Kurtosis:                       6.116   Cond. No.                         19.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Using matrix algebra to estimate the beta coefficients:
sr['constant'] = 1
selcols = ['constant','MXX']
x = sr[selcols].values
y = sr['ALFAA'].values

xtx = np.matmul(x.transpose(),x)
xty = np.matmul(x.transpose(),y)
invtxt = np.linalg.inv(xtx)

betas = np.matmul(invtxt,xty)
betas
# Out:
# array([-0.00786281,  1.53894487])

# %% [markdown]
# La beta0 es -0.0078 y la beta1 es 1.5389, lo cual representa una pendiente positiva.
